# %% [markdown]
# <a href="https://colab.research.google.com/github/design-smith/Web-Development/blob/master/Trident.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade --no-cache-dir git+https://github.com/rongardF/tvdatafeed.git
# Out:
# ...
#   Cloning https://github.com/rongardF/tvdatafeed.git to /tmp/pip-req-build-m_o83qkx
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed.git /tmp/pip-req-build-m_o83qkx
#   Resolved https://github.com/rongardF/tvdatafeed.git to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17533 sha256=369edcef7cd1deb66221f17bff8ba902e17b1f228dfae0725c18f290a84b201c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qwtoakq6/wheels/4b/f9/e9/82474a5d9a64702ba7dd5481dee05d267c69bcfa480d382b7c
# Successfully built tvdatafeed
# ...

# %%
from tvDatafeed import TvDatafeed, Interval

username = 'zwzeke@gmail.com'
password = 'Markets123$y35'

tv = TvDatafeed(username, password)

# %%
EURUSD_hist_data = tv.get_hist(symbol='EURUSD',exchange='OANDA',interval=Interval.in_1_hour,n_bars=100)
EURUSD_hist_data
# Out:
#                            symbol     open     high       low    close  volume
# datetime
# 2024-01-26 00:00:00  OANDA:EURUSD  1.08456  1.08460  1.083740  1.08400  1978.0
# 2024-01-26 01:00:00  OANDA:EURUSD  1.08400  1.08468  1.083920  1.08444  2476.0
# 2024-01-26 02:00:00  OANDA:EURUSD  1.08444  1.08490  1.084400  1.08444  1998.0
# 2024-01-26 03:00:00  OANDA:EURUSD  1.08444  1.08476  1.084380  1.08451  1421.0
# 2024-01-26 04:00:00  OANDA:EURUSD  1.08451  1.08452  1.083800  1.08397  1290.0
# ...                           ...      ...      ...       ...      ...     ...
# 2024-01-31 23:00:00  OANDA:EURUSD  1.08140  1.08172  1.080320  1.08040  1262.0
# 2024-02-01 00:00:00  OANDA:EURUSD  1.08040  1.08146  1.080200  1.08084  3050.0
# 2024-02-01 01:00:00  OANDA:EURUSD  1.08084  1.08127  1.080460  1.08090  3583.0
# 2024-02-01 02:00:00  OANDA:EURUSD  1.08090  1.08220  1.080855  1.08192  3215.0
# 2024-02-01 03:00:00  OANDA:EURUSD  1.08192  1.08210  1.081100  1.08147  1829.0
#
# ...
